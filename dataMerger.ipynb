# %%
import pandas as pd
import numpy as np

# %%
overall = pd.read_csv('data/output/overall3.csv')

# %%
income = pd.read_csv('data/output/income.csv')

# %%
overall.head(20)
income.head(470)
# Out:
#    stateProvince  avgIncome     index  adjustedIncome
# 0             AL   0.606150  1.077683        0.653237
# 1             AK   0.788807  0.753285        0.594196
# 2             AZ   0.624971  0.963283        0.602024
# 3             AR   0.591954  1.102970        0.652907
# 4             CA   0.769701  0.753636        0.580074
# 5             CO   0.764308  0.993123        0.759051
# 6             CT   1.000000  0.767620        0.767620
# 7             DE   0.713594  0.975976        0.696451
# 8             FL   0.701273  1.005170        0.704898
# 9             GA   0.633739  1.085363        0.687836
# 10            HI   0.732505  0.603363        0.441966
# 11            ID   0.576008  1.073831        0.618535
# 12            IL   0.770683  1.045794        0.805975
# 13            IN   0.623971  1.075746        0.671234
# 14            IA   0.683577  1.063179        0.726765
# 15            KS   0.709577  1.094350        0.776525
# ...

# %%
overall = overall.merge(income,how='outer')
#overall = overall.drop('Unnamed: 0',axis=1)

# %%
overall.head(500)
# Out:
#        i stateProvince                  city  jobs  clicks  localClicks  \
# 0      0            AK                  Adak     2     332           27
# 1      1            AK              Akiachak     3     426           41
# 2      2            AK             Anchorage   653  328090       110546
# 3      3            AK                Angoon     1      89            7
# 4      4            AK                 Aniak     4     155           18
# 5      5            AK                Barrow    14    4566          282
# 6      6            AK                Bethel    38   11211         1206
# 7      7            AK               Bettles     2      26            1
# 8      8            AK              Big Lake     1    1293           81
# 9      9            AK             Birchwood     1     630           53
# 10    10            AK              Buckland     1     465           23
# 11    11            AK               Chignik     1     946           94
# ...

# %%
overall.to_csv('data/overall4.csv')
