# %%
import pandas as pd
import numpy as np
import math
from datetime import datetime
from sklearn.linear_model import LinearRegression

# %%
# US Sample data
fulldata = pd.read_csv('data/Preprocessed.csv')

# %%
fulldata.shape
# Out:
# (14154437, 24)

# %%
# Generate Days Posted for each listing
df = fulldata
def get_diff(df):
    start = df['date'].min()
    end = df['date'].max()
    end_day = datetime.strptime(end, '%Y-%m-%d')
    start_day = datetime.strptime(start, '%Y-%m-%d')
    return (end_day-start_day).days + 1

listings = df.groupby(['stateProvince','city','jobId'])
dates = listings.apply(get_diff).reset_index(name="DaysPosted")
dates.shape
dates
# print("Finished calculating")
# dates.set_index('jobId')
# df.set_index('jobId')
# dates = dates.join(df, how='inner', lsuffix='_left', rsuffix='_right')
# print("Finished joining")
# city_listings = dates.groupby(['stateProvince', 'city'])['DaysPosted'].mean().reset_index(name='AvgDays')
# print("Finished aggregating")
# city_listings.head(20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-2fd030355a83> in <module>()
#       8     return (end_day-start_day).days + 1
#       9
# ---> 10 listings = df.groupby('stateProvince','city','jobId')
#      11 dates = listings.apply(get_diff).reset_index(name="DaysPosted")
#      12 dates.shape
#
# /usr/lib/python2.7/site-packages/pandas/core/generic.pyc in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    5157         if level is None and by is None:
#    5158             raise TypeError("You have to supply one of 'by' and 'level'")
# -> 5159         axis = self._get_axis_number(axis)
#    5160         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    5161                        sort=sort, group_keys=group_keys, squeeze=squeeze,
#
# ...

# %%
dates
# Out:
#              jobId  DaysPosted
# 0       job0000000           3
# 1       job0000001           5
# 2       job0000002           3
# 3       job0000003          13
# 4       job0000005          18
# 5       job0000006          19
# 6       job0000010          28
# 7       job0000015          35
# 8       job0000016          35
# 9       job0000017          36
# 10      job0000019           1
# 11      job0000021          35
# 12      job0000022           4
# 13      job0000024          55
# 14      job0000025          53
# 15      job0000026          26
# 16      job0000027          55
# 17      job0000028          58
# 18      job0000029          19
# 19      job0000030           1
# 20      job0000032          11
# 21      job0000033          60
# 22      job0000034          39
# 23      job0000035          11
# 24      job0000036           3
# 25      job0000037          61
# 26      job0000040          59
# 27      job0000042          12
# 28      job0000043          27
# ...

# %%
city_listings.shape
# Out:
# (15873, 3)

# %%
city_listings.to_csv('data/listing_time.csv')
print("Finished writing to csv")
# Out:
# Finished writing to csv

# %%
# Regression
lm = LinearRegression(n_jobs=-1)
independent = df[['']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-90-58b882dd31b1> in <module>()
#       1 # Regression
#       2 lm = LinearRegression()
# ----> 3 df['log_clicks'] = df.apply(lambda r: math.log(int(r['clicks'])+1))
#       4 lm.fit(df[['descriptionWordCount']], df['log_clicks'])
#       5 lm.score(df[['descriptionWordCount']], df['log_clicks'])
#
# ~\Miniconda3\envs\Datafest2018\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
# ...
