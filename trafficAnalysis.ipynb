# %%
import pandas as pd
import numpy as np

# %%
data_small = pd.read_csv('data/datafest2018_CANADA_SMALL.csv')

# %%
data_full = pd.read_csv('data/datafest2018NewApril6.csv')

# %%
data_full.shape
# Out:
# (17635296, 23)

# %%
def examplefunc(row):
    return row['country'] + row['stateProvince']

data_small['countrystate'] = data_small.apply(examplefunc, axis=1)
data_small.drop(['countrystate'],axis = 1)
# Out:
#              date      companyId       jobId country stateProvince  \
# 0      2016-10-02   company00203  job0000213      CA            ON
# 1      2016-10-02   company00290  job0000312      CA            ON
# 2      2016-10-05   company00784  job0000856      CA            ON
# 3      2016-10-05   company00862  job0000949      CA            ON
# 4      2016-10-06   company00003  job0001121      CA            ON
# 5      2016-10-06   company01055  job0001175      CA            AB
# 6      2016-10-06   company01090  job0001217      CA            ON
# 7      2016-10-07   company01177  job0001314      CA            QC
# 8      2016-10-07   company01193  job0001332      CA            BC
# 9      2016-10-08   company01291  job0001446      CA            ON
# 10     2016-10-09   company01463  job0001642      CA            BC
# 11     2016-10-09   company01526  job0001721      CA            ON
# 12     2016-10-10   company01610  job0001822      CA            QC
# ...
